# %% [markdown]
# # Ex2 - Filtering and Sorting Data

# %% [markdown]
# ### Step 1. Import the necessary libraries

# %%
import pandas as pd

# %%
pwd()
# Out:
# 'C:\\Users\\Hp\\Documents\\Assignment 2'

# %% [markdown]
# ### Step 2. Copy data to PWD & Import data

# %% [markdown]
# ### Step 3. Assign it to a variable called euro12.

# %%
euro12= pd.read_csv("EURO_stat.csv")
euro12
# Out:
#                    Team  Goals  Shots on target  Shots off target  \
# 0               Croatia      4               13                12
# 1        Czech Republic      4               13                18
# 2               Denmark      4               10                10
# 3               England      5               11                18
# 4                France      3               22                24
# 5               Germany     10               32                32
# 6                Greece      5                8                18
# 7                 Italy      6               34                45
# 8           Netherlands      2               12                36
# 9                Poland      2               15                23
# 10             Portugal      6               22                42
# 11  Republic of Ireland      1                7                12
# 12               Russia      5                9                31
# ...

# %%
euro_12=euro12.transpose()

# %% [markdown]
# euro_12

# %%
euro_12
# Out:
#                                  0               1        2        3       4   \
# Team                        Croatia  Czech Republic  Denmark  England  France
# Goals                             4               4        4        5       3
# Shots on target                  13              13       10       11      22
# Shots off target                 12              18       10       18      24
# Shooting Accuracy            51.90%          41.90%   50.00%   50.00%  37.90%
# % Goals-to-shots             16.00%          12.90%   20.00%   17.20%   6.50%
# Total shots (inc. Blocked)       32              39       27       40      65
# Hit Woodwork                      0               0        1        0       1
# Penalty goals                     0               0        0        0       0
# Penalties not scored              0               0        0        0       0
# Headed goals                      2               0        3        3       0
# ...

# %%
euro12.reset_index(inplace=True,drop=True)

# %%
euro12
# Out:
#                    Team  Goals  Shots on target  Shots off target  \
# 0               Croatia      4               13                12
# 1        Czech Republic      4               13                18
# 2               Denmark      4               10                10
# 3               England      5               11                18
# 4                France      3               22                24
# 5               Germany     10               32                32
# 6                Greece      5                8                18
# 7                 Italy      6               34                45
# 8           Netherlands      2               12                36
# 9                Poland      2               15                23
# 10             Portugal      6               22                42
# 11  Republic of Ireland      1                7                12
# 12               Russia      5                9                31
# ...

# %% [markdown]
# ### Step 4. Select only the Goal column.

# %%
euro12["Goals"]
# Out:
# 0      4
# 1      4
# 2      4
# 3      5
# 4      3
# 5     10
# 6      5
# 7      6
# 8      2
# 9      2
# 10     6
# 11     1
# 12     5
# 13    12
# 14     5
# 15     2
# Name: Goals, dtype: int64

# %% [markdown]
# ### Step 5. How many team participated in the Euro2012?

# %%
euro12["Team"].count()
# Out:
# 16

# %% [markdown]
# ### Step 6. What is the number of columns in the dataset?

# %%
print(df.nunique(axis=1))
# Out:
# 0     26
# 1     30
# 2     26
# 3     27
# 4     26
# 5     28
# 6     28
# 7     27
# 8     25
# 9     26
# 10    28
# 11    25
# 12    29
# 13    29
# 14    27
# 15    24
# dtype: int64

# %% [markdown]
# ### Step 7. View only the columns Team, Yellow Cards and Red Cards and assign them to a dataframe called discipline

# %%
euro12[["Team","Yellow_Cards","Red_Cards"]]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-72-8a09d272f071> in <module>
# ----> 1 euro12[["Team","Yellow_Cards","Red_Cards"]]
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2906             if is_iterator(key):
#    2907                 key = list(key)
# -> 2908             indexer = self.loc._get_listlike_indexer(key, axis=1, raise_missing=True)[1]
#    2909
#    2910         # take() does not accept boolean indexers
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1252             keyarr, indexer, new_indexer = ax._reindex_non_unique(keyarr)
#    1253
# -> 1254         self._validate_read_indexer(keyarr, indexer, axis, raise_missing=raise_missing)
#    1255         return keyarr, indexer
#    1256
#
# ...

# %%
euro12.set_index(['Team','Yellow_Cards','Red_Cards'])
euro12[["Team","Yellow_Cards","Red_Cards"]]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-63-669148bcaeef> in <module>
# ----> 1 euro12.set_index(['Team','Yellow_Cards','Red_Cards'])
#       2 euro12[["Team","Yellow_Cards","Red_Cards"]]
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in set_index(self, keys, drop, append, inplace, verify_integrity)
#    4549
#    4550         if missing:
# -> 4551             raise KeyError(f"None of {missing} are in the columns")
#    4552
#    4553         if inplace:
#
# KeyError: "None of ['Yellow_Cards', 'Red_Cards'] are in the columns"

# %% [markdown]
# ### Step 8. Sort the teams by Red Cards, then to Yellow Cards

# %% [markdown]
# ### Step 9. Calculate the mean Yellow Cards given per Team

# %% [markdown]
# ### Step 10. Filter teams that scored more than 6 goals

# %% [markdown]
# ### Step 11. Select the teams that start with G

# %% [markdown]
# ### Step 12. Select the first 7 columns

# %%
euro12.head(7)
# Out:
#              Team  Goals  Shots on target  Shots off target Shooting Accuracy  \
# 0         Croatia      4               13                12            51.90%
# 1  Czech Republic      4               13                18            41.90%
# 2         Denmark      4               10                10            50.00%
# 3         England      5               11                18            50.00%
# 4          France      3               22                24            37.90%
# 5         Germany     10               32                32            47.80%
# 6          Greece      5                8                18            30.70%
#
#   % Goals-to-shots  Total shots (inc. Blocked)  Hit Woodwork  Penalty goals  \
# 0           16.00%                          32             0              0
# 1           12.90%                          39             0              0
# 2           20.00%                          27             1              0
# ...

# %% [markdown]
# ### Step 13. Select all columns except the last 3.

# %%
print(euro12[euro12.columns[:-3]])
# Out:
#                    Team  Goals  Shots on target  Shots off target  \
# 0               Croatia      4               13                12
# 1        Czech Republic      4               13                18
# 2               Denmark      4               10                10
# 3               England      5               11                18
# 4                France      3               22                24
# 5               Germany     10               32                32
# 6                Greece      5                8                18
# 7                 Italy      6               34                45
# 8           Netherlands      2               12                36
# 9                Poland      2               15                23
# 10             Portugal      6               22                42
# 11  Republic of Ireland      1                7                12
# 12               Russia      5                9                31
# ...

# %% [markdown]
# ### Step 14. Present only the Shooting Accuracy from England, Italy and Russia

# %%
print(euro12.loc[2:5:12,['Team', 'Shooting_Accuracy']])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-69-2078278c89a1> in <module>
# ----> 1 print(euro12.loc[1:3,['Team', 'Shooting_Accuracy']])
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#     871                     # AttributeError for IntervalTree get_value
#     872                     pass
# --> 873             return self._getitem_tuple(key)
#     874         else:
#     875             # we by definition only have the 0th axis
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_tuple(self, tup)
#    1053             return self._multi_take(tup)
#    1054
# -> 1055         return self._getitem_tuple_same_dim(tup)
#    1056
#    1057     def _get_label(self, label, axis: int):
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_tuple_same_dim(self, tup)
# ...
